# %% [markdown]
# <a href="https://colab.research.google.com/github/FATHIMARINSHA-KP/web-scraping-using-python-task/blob/main/Web_Scraping_Exercises.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Web Scraping Exercises
#
# ## Complete the Tasks Below

# %% [markdown]
# **TASK: Import any libraries you think you'll need to scrape a website.**

# %%
import requests

# %%
import bs4

# %% [markdown]
# **TASK: Use requests library and BeautifulSoup to connect to http://quotes.toscrape.com/ and get the HMTL text from the homepage.**

# %%
import requests

from bs4 import BeautifulSoup

url = "https://quotes.toscrape.com/"

response = requests.get(url)

soup = BeautifulSoup(response.text,"html.parser")

text = soup.find_all("span",class_="text")

for i in text:
  print(i.text)
# Out:
# “The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”
# “It is our choices, Harry, that show what we truly are, far more than our abilities.”
# “There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”
# “The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”
# “Imperfection is beauty, madness is genius and it's better to be absolutely ridiculous than absolutely boring.”
# “Try not to become a man of success. Rather become a man of value.”
# “It is better to be hated for what you are than to be loved for what you are not.”
# “I have not failed. I've just found 10,000 ways that won't work.”
# “A woman is like a tea bag; you never know how strong it is until it's in hot water.”
# “A day without sunshine is like, you know, night.”

# %% [markdown]
# **TASK: Get the names of all the authors on the first page.**

# %%
text = soup.find_all("small",class_="author")

for i in text:
  print(i.text)
# Out:
# Albert Einstein
# J.K. Rowling
# Albert Einstein
# Jane Austen
# Marilyn Monroe
# Albert Einstein
# André Gide
# Thomas A. Edison
# Eleanor Roosevelt
# Steve Martin

# %% [markdown]
# **TASK: Create a list of all the quotes on the first page.**

# %%
qoutes = []
quote = soup.find_all("span",class_="text")

for i in quote:
  qoutes.append(i.text)
  print(qoutes)
# Out:
# ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”']
# ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”', '“It is our choices, Harry, that show what we truly are, far more than our abilities.”']
# ['“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”', '“It is our choices, Harry, that show what we truly are, far more than our abilities.”', '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”']
# ...

# %% [markdown]
# **TASK: Inspect the site and use Beautiful Soup to extract the top ten tags from the requests text shown on the top right from the home page (e.g Love,Inspirational,Life, etc...). HINT: Keep in mind there are also tags underneath each quote, try to find a class only present in the top right tags, perhaps check the span.**

# %%
tags = soup.find_all("span",class_="tag-item")

for i in tags[:10]:

  print(i.text.strip())
# Out:
# love
# inspirational
# life
# humor
# books
# reading
# friendship
# friends
# truth
# simile

# %% [markdown]
# **TASK: Notice how there is more than one page, and subsequent pages look like this http://quotes.toscrape.com/page/2/. Use what you know about for loops and string concatenation to loop through all the pages and get all the unique authors on the website.

# %%
import requests
from bs4 import BeautifulSoup

unique_authors = set()

for page in range(1, 11):

    url = f"https://quotes.toscrape.com/page/{page}/"

    response = requests.get(url)

    soup = BeautifulSoup(response.text, "html.parser")

    authors = soup.find_all("small", class_="author")

    for author in authors:
        unique_authors.add(author.text)



for name in unique_authors:
    print(name)
# Out:
# Unique Authors:
#
# Haruki Murakami
# Pablo Neruda
# Jimi Hendrix
# Douglas Adams
# Ayn Rand
# Friedrich Nietzsche
# J.M. Barrie
# Elie Wiesel
# Terry Pratchett
# Thomas A. Edison
# Marilyn Monroe
# Alfred Tennyson
# George R.R. Martin
# Martin Luther King Jr.
# Suzanne Collins
# George Eliot
# Harper Lee
# Bob Marley
# Eleanor Roosevelt
# Charles M. Schulz
# James Baldwin
# Alexandre Dumas fils
# Ernest Hemingway
# John Lennon
# Dr. Seuss
# W.C. Fields
# Allen Saunders
# Albert Einstein
# Madeleine L'Engle
# J.K. Rowling
# Jim Henson
# Mother Teresa
# Khaled Hosseini
# André Gide
# Helen Keller
# Garrison Keillor
# Steve Martin
# Jorge Luis Borges
# George Bernard Shaw
# Jane Austen
# J.D. Salinger
# C.S. Lewis
# Ralph Waldo Emerson
# George Carlin
# William Nicholson
# Stephenie Meyer
# E.E. Cummings
# Mark Twain
# Charles Bukowski
# J.R.R. Tolkien
